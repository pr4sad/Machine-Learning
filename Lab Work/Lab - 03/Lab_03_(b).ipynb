# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sn
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['Species']=data['Species'].replace({'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3})
# Out:
# <ipython-input-28-f00f9a0a6342>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Species']=data['Species'].replace({'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3})

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        3
# 146  147            6.3           2.5            5.0           1.9        3
# 147  148            6.5           3.0            5.2           2.0        3
# 148  149            6.2           3.4            5.4           2.3        3
# 149  150            5.9           3.0            5.1           1.8        3
#
# [150 rows x 6 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],data['Species'], test_size=0.4)

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 117            7.7           3.8            6.7           2.2
# 109            7.2           3.6            6.1           2.5
# 84             5.4           3.0            4.5           1.5
# 125            7.2           3.2            6.0           1.8
# 81             5.5           2.4            3.7           1.0
# ..             ...           ...            ...           ...
# 31             5.4           3.4            1.5           0.4
# 52             6.9           3.1            4.9           1.5
# 63             6.1           2.9            4.7           1.4
# 3              4.6           3.1            1.5           0.2
# 87             6.3           2.3            4.4           1.3
#
# [90 rows x 4 columns]

# %%
y_train
# Out:
# 117    3
# 109    3
# 84     2
# 125    3
# 81     2
#       ..
# 31     1
# 52     2
# 63     2
# 3      1
# 87     2
# Name: Species, Length: 90, dtype: int64

# %%
from sklearn import linear_model
model=linear_model.LogisticRegression(max_iter=100)
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([2, 3, 1, 3, 2, 1, 2, 2, 2, 3, 2, 3, 3, 3, 3, 3, 3, 1, 2, 1, 3, 3,
#        2, 2, 2, 1, 2, 2, 3, 1, 1, 2, 3, 3, 2, 1, 3, 1, 1, 3, 3, 3, 1, 3,
#        2, 1, 2, 2, 1, 1, 3, 1, 2, 2, 3, 3, 3, 1, 3, 2])

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 86             6.7           3.1            4.7           1.5
# 138            6.0           3.0            4.8           1.8
# 47             4.6           3.2            1.4           0.2
# 137            6.4           3.1            5.5           1.8
# 73             6.1           2.8            4.7           1.2
# 40             5.0           3.5            1.3           0.3
# 75             6.6           3.0            4.4           1.4
# 56             6.3           3.3            4.7           1.6
# 69             5.6           2.5            3.9           1.1
# 101            5.8           2.7            5.1           1.9
# 90             5.5           2.6            4.4           1.2
# 116            6.5           3.0            5.5           1.8
# 130            7.4           2.8            6.1           1.9
# 149            5.9           3.0            5.1           1.8
# 105            7.6           3.0            6.6           2.1
# 113            5.7           2.5            5.0           2.0
# 115            6.4           3.2            5.3           2.3
# 15             5.7           4.4            1.5           0.4
# 68             6.2           2.2            4.5           1.5
# 28             5.2           3.4            1.4           0.2
# 128            6.4           2.8            5.6           2.1
# 112            6.8           3.0            5.5           2.1
# 95             5.7           3.0            4.2           1.2
# 54             6.5           2.8            4.6           1.5
# 91             6.1           3.0            4.6           1.4
# 17             5.1           3.5            1.4           0.3
# 99             5.7           2.8            4.1           1.3
# 80             5.5           2.4            3.8           1.1
# 129            7.2           3.0            5.8           1.6
# 11             4.8           3.4            1.6           0.2
# 27             5.2           3.5            1.5           0.2
# 60             5.0           2.0            3.5           1.0
# 144            6.7           3.3            5.7           2.5
# 100            6.3           3.3            6.0           2.5
# 88             5.6           3.0            4.1           1.3
# 18             5.7           3.8            1.7           0.3
# 134            6.1           2.6            5.6           1.4
# 26             5.0           3.4            1.6           0.4
# 38             4.4           3.0            1.3           0.2
# 146            6.3           2.5            5.0           1.9
# 131            7.9           3.8            6.4           2.0
# 132            6.4           2.8            5.6           2.2
# 42             4.4           3.2            1.3           0.2
# 139            6.9           3.1            5.4           2.1
# 94             5.6           2.7            4.2           1.3
# 25             5.0           3.0            1.6           0.2
# 92             5.8           2.6            4.0           1.2
# 71             6.1           2.8            4.0           1.3
# 32             5.2           4.1            1.5           0.1
# 2              4.7           3.2            1.3           0.2
# 140            6.7           3.1            5.6           2.4
# 0              5.1           3.5            1.4           0.2
# 53             5.5           2.3            4.0           1.3
# 50             7.0           3.2            4.7           1.4
# 121            5.6           2.8            4.9           2.0
# 118            7.7           2.6            6.9           2.3
# 108            6.7           2.5            5.8           1.8
# 5              5.4           3.9            1.7           0.4
# 122            7.7           2.8            6.7           2.0
# 76             6.8           2.8            4.8           1.4

# %%
input_data = pd.DataFrame([[4.6, 3.2, 1.4, 0.2]], columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
model.predict(input_data)
# Out:
# array([1])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
conf_mat=confusion_matrix(y_test,model.predict(x_test))
conf_mat
# Out:
# array([[16,  0,  0],
#        [ 0, 20,  0],
#        [ 0,  0, 24]])

# %%
plt.figure(figsize = (5,4))
sn.heatmap(conf_mat, annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth or Actual Value')
# Out:
# Text(33.22222222222222, 0.5, 'Truth or Actual Value')
